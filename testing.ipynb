# %%
import json
from collections import Counter
from pathlib import Path

import kagglehub
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Download latest version
recipe_path = Path(kagglehub.dataset_download("shuyangli94/foodcom-recipes-with-search-terms-and-tags"))
cuisine_path = Path(kagglehub.dataset_download("kaggle/recipe-ingredients-dataset"))

print("Path to cuisine dataset files:", cuisine_path)
print("Path to recipe dataset files:", recipe_path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kaggle/recipe-ingredients-dataset?dataset_version_number=1...
# 100%|██████████| 2.23M/2.23M [00:00<00:00, 6.35MB/s]
# Extracting files...
# Path to cuisine dataset files: /home/nates/.cache/kagglehub/datasets/kaggle/recipe-ingredients-dataset/versions/1
# Path to recipe dataset files: /home/nates/.cache/kagglehub/datasets/shuyangli94/foodcom-recipes-with-search-terms-and-tags/versions/2

# %%
df = pd.read_csv(recipe_path / "recipes_w_search_terms.csv")

# %%
df
# Out:
#             id                                      name  \
# 0        96313               Grilled Garlic Cheese Grits
# 1       232037     Simple Shrimp and Andouille Jambalaya
# 2        41090                black-and-white bean salad
# 3        60656                Crock Pot Italian Zucchini
# 4       232047             Beef Stew With Dried Cherries
# ...        ...                                       ...
# 494958  276465                  Blackberry Orange Scones
# 494959  257796  Slow Cooker Garlic Chicken With Rosemary
# 494960   78003           Pot Roast with Port (Stove Top)
# 494961  328810          Kapusta ( Cabbage and Kielbasa )
# 494962    9116             Yellow or Zucchini Squash Pie
#
#                                               description  \
# 0       We love grits, this is another good way to ser...
# 1       Simple, easy and very tasty for when you are i...
# 2                                                     NaN
# 3       This is a good recipe for weight watchers. It ...
# 4       This is a fabulous stew that came from one of ...
# ...                                                   ...
# 494958  The orange zest makes for a flavorful, not ove...
# 494959                                Delicious and easy!
# 494960  This is a recipe from the Frugal Gourmet cooki...
# 494961                Cabbage and sausage in tomato sauce
# 494962  This recipe was given to my mom from a lady wh...
#
#                                               ingredients  \
# 0       ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1       ['onion', 'red bell pepper', 'garlic cloves', ...
# 2       ['white beans', 'canned black beans', 'tomatoe...
# 3       ['zucchini', 'yellow squash', 'diced tomatoes'...
# 4       ['beef stew meat', 'flour', 'salt', 'allspice'...
# ...                                                   ...
# 494958  ['unbleached flour', 'baking soda', 'butter', ...
# 494959  ['roasting chickens', 'lemons', 'rosemary spri...
# 494960  ['boneless beef chuck roast', 'olive oil', 'ta...
# 494961  ['cabbage', 'condensed tomato soup', 'kielbasa...
# 494962  ['zucchini', 'onion', 'butter', 'oregano', 'ba...
#
#                                       ingredients_raw_str serving_size  \
# 0       ["4   cups    water","1   cup   uncooked old f...    1 (155 g)
# 1       ["1   medium    onion, chopped coarse ","1   m...    1 (366 g)
# 2       ["1   cup   canned white beans, rinsed and dra...    1 (807 g)
# 3       ["2       zucchini, sliced ","2   small    yel...    1 (244 g)
# 4       ["3   lbs    beef stew meat","3   tablespoons ...    1 (358 g)
# ...                                                   ...          ...
# 494958  ["2 1/2  cups    unbleached flour","2   teaspo...     1 (83 g)
# 494959  ["1 (5   lb)    roasting chickens, rinsed and ...    1 (340 g)
# 494960  ["2 -3   lbs    boneless beef chuck roast","2 ...    1 (283 g)
# 494961  ["8   cups    cabbage or 2   heads    cabbage,...    1 (564 g)
# 494962  ["4   cups    zucchini (can mix the squash if ...    1 (160 g)
#
#         servings                                              steps  \
# 0              8  ['I a sauce pan, bring water to a boil; slowly...
# 1              4  ['In a food processor, pulse the onion, red pe...
# 2              1  ['In a large bowl, combine beans, tomato, onio...
# 3              4  ['Put all ingredients in the crock pot and coo...
# 4              8  ['Preheat oven to 350°F.', "Cut beef into 1 in...
# ...          ...                                                ...
# 494958         8  ['Sift about 2 cups of flour onto a piece of w...
# 494959         6  ['Place rosemary springs, 1 lemon half, celery...
# 494960         4  ['In a large pan, heat oil and brown roast on ...
# 494961         6  ['Saute bacon in large pan until browned.  Lea...
# 494962         6  ['Melt butter in skillet. Add squash, onions, ...
#
#                                                      tags  \
# 0       ['time-to-make', 'course', 'main-ingredient', ...
# 1       ['60-minutes-or-less', 'time-to-make', 'course...
# 2       ['15-minutes-or-less', 'time-to-make', 'course...
# 3       ['weeknight', 'time-to-make', 'course', 'main-...
# 4       ['time-to-make', 'course', 'main-ingredient', ...
# ...                                                   ...
# 494958  ['30-minutes-or-less', 'time-to-make', 'course...
# 494959  ['main-ingredient', 'preparation', 'occasion',...
# 494960  ['weeknight', 'time-to-make', 'course', 'prepa...
# 494961  ['time-to-make', 'course', 'preparation', 'mai...
# 494962  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                              search_terms
# 0       {'diabetic', 'low-calorie', 'vegetarian', 'low...
# 1                                    {'dinner', 'shrimp'}
# 2       {'vegetarian', 'salad', 'side', 'dinner', 'veg...
# 3                       {'side', 'vegetarian', 'italian'}
# 4                                              {'dinner'}
# ...                                                   ...
# 494958                             {'breakfast', 'bread'}
# 494959                              {'dinner', 'chicken'}
# 494960      {'roast', 'dinner', 'low-sodium', 'low-carb'}
# 494961                                         {'dinner'}
# 494962              {'southern', 'pie', 'dinner', 'side'}
#
# [494963 rows x 10 columns]

# %%
search_terms_counter = Counter()

# %%
for search_terms in df["search_terms"]:
    search_terms = json.loads(search_terms.replace('\'', '"').replace('{', '[').replace('}', ']'))

    search_terms_counter.update(search_terms)

# %%
search_terms_counter
# Out:
# Counter({'dinner': 215836,
#          'dessert': 116357,
#          'low-sodium': 94179,
#          'low-carb': 89649,
#          'low-calorie': 76517,
#          'healthy': 70941,
#          'vegetarian': 69038,
#          'side': 52576,
#          'low-fat': 48050,
#          'appetizer': 47845,
#          'chicken': 46440,
#          'lunch': 45056,
#          'breakfast': 31198,
#          'salad': 29113,
#          'bread': 27818,
#          'soup': 21121,
#          'vegan': 20402,
#          'cake': 20037,
#          'italian': 17068,
#          'snack': 16816,
#          'southern': 15844,
#          'mexican': 15629,
#          'cookie': 14918,
#          'diabetic': 13453,
#          'pasta': 12926,
#          'casserole': 11947,
#          'pork': 11861,
#          'pie': 11849,
#          'gluten-free': 11809,
#          'beef': 10676,
#          'rice': 10518,
#          'baked': 8522,
#          'fish': 8405,
#          'french': 8049,
#          'shrimp': 7917,
#          'lactose-free': 7695,
#          'indian': 6566,
#          'sandwich': 5661,
#          'pizza': 5474,
#          'pudding': 5468,
#          'chinese': 5004,
#          'greek': 4966,
#          'stew': 4741,
#          'roast': 4206,
#          'noodles': 4054,
#          'english': 3978,
#          'barbecue': 3878,
#          'thai': 3254,
#          'caribbean': 3186,
#          'german': 3121,
#          'quick': 2666,
#          'spanish': 2623,
#          'lamb': 2458,
#          'japanese': 2162,
#          'irish': 1886,
#          'moroccan': 1795,
#          'light': 1374,
#          'scottish': 1338,
#          'cajun': 1229,
#          'seafood': 1185,
#          'russian': 1067,
#          'braised': 1041,
#          'polish': 839,
#          'vietnamese': 782,
#          'sugar-free': 774,
#          'creole': 713,
#          'cuban': 642,
#          'korean': 642,
#          'drink': 609,
#          'turkish': 583,
#          'lebanese': 562,
#          'diet': 505,
#          'dairy-free': 499,
#          'fat-free': 497,
#          'brazilian': 451,
#          'indonesian': 435,
#          'american': 408,
#          'egyptian': 363,
#          'jamaican': 347,
#          'low-sugar': 327,
#          'peruvian': 265,
#          'malaysian': 263,
#          'flourless': 252,
#          'persian': 202,
#          'ethiopian': 182,
#          'chilean': 162,
#          'meatless': 138,
#          'atkins': 72,
#          'nigerian': 65,
#          'grain-free': 56,
#          'lowfat': 51,
#          'sugarless': 43,
#          'salt-free': 38,
#          'no flour': 20,
#          'no meat': 11,
#          'carb-free': 7,
#          'sodium-free': 4,
#          'flour-less': 3})

# %%
search_terms, counts = zip(*search_terms_counter.most_common(10))

plt.bar(search_terms, counts)
plt.xticks(rotation=30)
plt.xlabel("Search Terms")
plt.ylabel("Occurences In Recipes")
plt.title("Top 10 Most Common Search Terms In Recipes")
plt.show()

# %%
ingredient_counter = Counter()

# %%
for ingredient_list in df["ingredients"]:
    ingredient_list = json.loads(ingredient_list.replace('\'', '"'))

    ingredient_counter.update(ingredient_list)

# %%
ingredient_counter
# Out:
# Counter({'salt': 191553,
#          'butter': 128360,
#          'sugar': 109627,
#          'onion': 84310,
#          'eggs': 78881,
#          'water': 77926,
#          'olive oil': 72813,
#          'flour': 60363,
#          'milk': 57517,
#          'garlic cloves': 57049,
#          'pepper': 47465,
#          'all-purpose flour': 41960,
#          'brown sugar': 40624,
#          'baking powder': 38463,
#          'egg': 38285,
#          'garlic': 34051,
#          'vanilla': 32529,
#          'baking soda': 32146,
#          'salt and pepper': 31692,
#          'parmesan cheese': 31101,
#          'vegetable oil': 30255,
#          'lemon juice': 30051,
#          'cinnamon': 28038,
#          'black pepper': 27203,
#          'vanilla extract': 26729,
#          'tomatoes': 26063,
#          'sour cream': 25866,
#          'unsalted butter': 24271,
#          'cream cheese': 23052,
#          'garlic clove': 22091,
#          'oil': 22007,
#          'celery': 21778,
#          'garlic powder': 21764,
#          'onions': 21165,
#          'honey': 20371,
#          'soy sauce': 18511,
#          'cheddar cheese': 18130,
#          'mayonnaise': 17919,
#          'extra virgin olive oil': 17268,
#          'chicken broth': 17239,
#          'cornstarch': 17207,
#          'worcestershire sauce': 16229,
#          'carrots': 16017,
#          'paprika': 15935,
#          'granulated sugar': 15859,
#          'chili powder': 15510,
#          'fresh parsley': 15500,
#          'parsley': 15376,
#          'ground cinnamon': 15346,
#          'fresh ground black pepper': 15206,
#          'carrot': 15007,
#          'bacon': 14682,
#          'kosher salt': 14208,
#          'nutmeg': 14103,
#          'pecans': 13843,
#          'potatoes': 13586,
#          'heavy cream': 13445,
#          'powdered sugar': 13432,
#          'ground beef': 13146,
#          'walnuts': 13142,
#          'red onion': 12858,
#          'cayenne pepper': 12813,
#          'ground cumin': 12539,
#          'green onions': 12138,
#          'green onion': 11985,
#          'margarine': 11556,
#          'dijon mustard': 11095,
#          'fresh lemon juice': 10965,
#          'mozzarella cheese': 10667,
#          'canola oil': 10013,
#          'zucchini': 9928,
#          'tomato sauce': 9920,
#          'dried oregano': 9872,
#          'raisins': 9852,
#          'tomato paste': 9667,
#          'red bell pepper': 9615,
#          'orange juice': 9612,
#          'green pepper': 9595,
#          'fresh cilantro': 9454,
#          'chicken stock': 9304,
#          'cumin': 9273,
#          'oregano': 9016,
#          'cilantro': 8882,
#          'ground black pepper': 8591,
#          'buttermilk': 8449,
#          'fresh ginger': 8374,
#          'egg whites': 8275,
#          'ginger': 8066,
#          'ketchup': 8050,
#          'boneless skinless chicken breasts': 8021,
#          'diced tomatoes': 7988,
#          'lime juice': 7892,
#          'confectioners%27 sugar': 7874,
#          'sea salt': 7804,
#          'ground ginger': 7722,
#          'egg yolks': 7633,
#          'fresh basil': 7588,
#          'whipping cream': 7552,
#          'balsamic vinegar': 7538,
#          'vinegar': 7366,
#          'white sugar': 7345,
#          'onion powder': 7224,
#          'light brown sugar': 7161,
#          'green bell pepper': 7096,
#          'dried thyme': 7064,
#          'bay leaf': 7050,
#          'whole wheat flour': 7026,
#          'salt %26 freshly ground black pepper': 6966,
#          'red wine vinegar': 6797,
#          'shortening': 6715,
#          'dry white wine': 6687,
#          'lemon': 6674,
#          'chicken breasts': 6628,
#          'thyme': 6602,
#          'cheese': 6547,
#          'fresh ground pepper': 6399,
#          'ground nutmeg': 6310,
#          'bananas': 6271,
#          'dried basil': 6261,
#          'sesame oil': 6209,
#          'mushrooms': 6198,
#          'breadcrumbs': 6179,
#          'curry powder': 6170,
#          'basil': 6155,
#          'boiling water': 6061,
#          'white wine': 6048,
#          'crushed red pepper flakes': 6028,
#          'white pepper': 6025,
#          'salsa': 5995,
#          'bay leaves': 5852,
#          'semi-sweet chocolate chips': 5844,
#          'black beans': 5777,
#          'nuts': 5591,
#          'dry mustard': 5515,
#          'chicken': 5416,
#          'garlic salt': 5409,
#          'scallions': 5390,
#          'red pepper flakes': 5387,
#          'red pepper': 5359,
#          'yellow onion': 5344,
#          'sharp cheddar cheese': 5271,
#          'peanut butter': 5241,
#          'cider vinegar': 5215,
#          'monterey jack cheese': 5163,
#          'lean ground beef': 5132,
#          'ground cloves': 5125,
#          'chocolate chips': 5091,
#          'apples': 5084,
#          'evaporated milk': 5070,
#          'fresh thyme': 5062,
#          'cold water': 5009,
#          'shallots': 4902,
#          'feta cheese': 4842,
#          'half-and-half': 4812,
#          'whole milk': 4791,
#          'almond extract': 4764,
#          'lemon zest': 4757,
#          'cucumber': 4744,
#          'shallot': 4741,
#          'cream': 4738,
#          'banana': 4720,
#          'fresh lime juice': 4713,
#          'hot sauce': 4671,
#          'celery ribs': 4660,
#          'cream of mushroom soup': 4642,
#          'shrimp': 4634,
#          'tabasco sauce': 4586,
#          'cooking spray': 4538,
#          'warm water': 4527,
#          'beef broth': 4521,
#          'black olives': 4482,
#          'salt %26 pepper': 4476,
#          'sesame seeds': 4472,
#          'skim milk': 4465,
#          'maple syrup': 4451,
#          'white vinegar': 4421,
#          'cocoa': 4391,
#          'mushroom': 4327,
#          'almonds': 4326,
#          'avocado': 4317,
#          'cooked chicken': 4297,
#          'green chilies': 4292,
#          'swiss cheese': 4246,
#          'sweetened condensed milk': 4189,
#          'italian seasoning': 4166,
#          'bread': 4165,
#          'lemon%2c juice of': 4105,
#          'fresh mushrooms': 4103,
#          'molasses': 4085,
#          'dark brown sugar': 4041,
#          'seasoning salt': 3981,
#          'cabbage': 3972,
#          'chives': 3945,
#          'sliced mushrooms': 3931,
#          'corn': 3922,
#          'ground coriander': 3887,
#          'hot water': 3875,
#          'cherry tomatoes': 3864,
#          'plain yogurt': 3855,
#          'flour tortillas': 3854,
#          'fresh rosemary': 3785,
#          'cocoa powder': 3751,
#          'lettuce': 3740,
#          'cayenne': 3738,
#          'egg white': 3733,
#          'ham': 3710,
#          'pure vanilla extract': 3703,
#          'cream of chicken soup': 3694,
#          'turmeric': 3640,
#          'rice': 3605,
#          'coconut milk': 3558,
#          'apple': 3545,
#          'bell pepper': 3520,
#          'coconut': 3517,
#          'orange zest': 3516,
#          'peanut oil': 3510,
#          'red wine': 3461,
#          'allspice': 3457,
#          'pine nuts': 3442,
#          'crushed pineapple': 3440,
#          'frozen peas': 3434,
#          'scallion': 3431,
#          'capers': 3421,
#          'rolled oats': 3415,
#          'caster sugar': 3410,
#          'barbecue sauce': 3406,
#          'green beans': 3396,
#          'ricotta cheese': 3393,
#          'egg yolk': 3384,
#          'cooked rice': 3381,
#          'plain flour': 3357,
#          'sweet potatoes': 3345,
#          'broccoli': 3316,
#          'boneless skinless chicken breast halves': 3316,
#          'potato': 3304,
#          'cornmeal': 3276,
#          'icing sugar': 3223,
#          'rice vinegar': 3221,
#          'cool whip': 3197,
#          'fresh dill': 3163,
#          'spinach': 3148,
#          'white onion': 3081,
#          'rosemary': 3071,
#          'strawberries': 3068,
#          'fresh chives': 3059,
#          'vegetable broth': 3041,
#          'cooking oil': 3034,
#          'active dry yeast': 3004,
#          'flat leaf parsley': 2996,
#          'apple cider vinegar': 2991,
#          'jalapeno pepper': 2970,
#          'blueberries': 2966,
#          'lime': 2944,
#          'white wine vinegar': 2943,
#          'light corn syrup': 2940,
#          'red potatoes': 2898,
#          'fish sauce': 2892,
#          'heavy whipping cream': 2852,
#          'gingerroot': 2842,
#          'mustard': 2838,
#          'whipped cream': 2828,
#          'slivered almonds': 2798,
#          'unsweetened cocoa powder': 2775,
#          'dried cranberries': 2774,
#          'sliced almonds': 2773,
#          'beer': 2764,
#          'vegetable stock': 2759,
#          'sweet onion': 2747,
#          'cream of tartar': 2735,
#          'low sodium chicken broth': 2734,
#          'of fresh mint': 2725,
#          'chickpeas': 2678,
#          'applesauce': 2674,
#          'jalapeno': 2645,
#          'crushed tomatoes': 2592,
#          'clove': 2591,
#          'dried parsley': 2562,
#          'ground allspice': 2560,
#          'vanilla ice cream': 2558,
#          'kidney beans': 2535,
#          'plum tomatoes': 2531,
#          'pineapple juice': 2514,
#          'dry sherry': 2486,
#          'yeast': 2485,
#          'hot pepper sauce': 2481,
#          'pasta': 2479,
#          'blue cheese': 2475,
#          'fresh spinach': 2471,
#          'lemons': 2464,
#          'strawberry': 2442,
#          'frozen chopped spinach': 2428,
#          'spaghetti': 2422,
#          'graham cracker crumbs': 2419,
#          'ground turkey': 2413,
#          'coarse salt': 2405,
#          'bread flour': 2403,
#          'red onions': 2400,
#          'boneless skinless chicken breast': 2396,
#          'pumpkin': 2391,
#          'hard-boiled eggs': 2372,
#          'semisweet chocolate': 2370,
#          'cauliflower': 2365,
#          'ice': 2358,
#          'coriander': 2352,
#          'ground pepper': 2341,
#          'white bread': 2330,
#          'fresh strawberries': 2324,
#          'brandy': 2311,
#          'avocados': 2297,
#          'corn tortillas': 2296,
#          'shredded cheddar cheese': 2295,
#          'orange': 2292,
#          'cake flour': 2292,
#          'asparagus': 2282,
#          'red bell peppers': 2260,
#          'prepared mustard': 2246,
#          'french bread': 2245,
#          'taco seasoning': 2231,
#          'baby spinach': 2221,
#          'splenda sugar substitute': 2214,
#          'basil leaves': 2199,
#          'beef stock': 2190,
#          'spaghetti sauce': 2180,
#          'leeks': 2143,
#          'apple juice': 2139,
#          'dried rosemary': 2134,
#          'cottage cheese': 2128,
#          'creamy peanut butter': 2127,
#          'fresh oregano': 2115,
#          'peanuts': 2104,
#          'chili sauce': 2103,
#          'romaine lettuce': 2080,
#          'ground pork': 2078,
#          'dates': 2068,
#          'tortilla chips': 2061,
#          'peaches': 2051,
#          'elbow macaroni': 2046,
#          'oatmeal': 2035,
#          'flaked coconut': 2027,
#          'green peppers': 2027,
#          'pork tenderloin': 2017,
#          'dry red wine': 2016,
#          'velveeta cheese': 2016,
#          'cinnamon stick': 1997,
#          'frozen corn': 1994,
#          'sherry wine': 1960,
#          'salmon fillets': 1959,
#          'oats': 1953,
#          'lemon peel': 1950,
#          'stewed tomatoes': 1946,
#          'lime%2c juice of': 1946,
#          'bittersweet chocolate': 1930,
#          'lemon%2c zest of': 1929,
#          'cumin seed': 1923,
#          'roma tomatoes': 1895,
#          'yellow cake mix': 1887,
#          'jalapeno peppers': 1887,
#          'cucumbers': 1887,
#          'leek': 1881,
#          'jalapenos': 1877,
#          'baby carrots': 1872,
#          'butternut squash': 1872,
#          'orange rind': 1864,
#          'eggplant': 1848,
#          'nonfat milk': 1843,
#          'ground red pepper': 1840,
#          'dry breadcrumbs': 1839,
#          'pork chops': 1834,
#          'celery seed': 1834,
#          'unbleached all-purpose flour': 1814,
#          'chopped tomatoes': 1812,
#          'vodka': 1806,
#          'salt and black pepper': 1801,
#          'rum': 1789,
#          'low sodium soy sauce': 1785,
#          'goat cheese': 1779,
#          'pumpkin pie spice': 1774,
#          'hoisin sauce': 1771,
#          'crabmeat': 1767,
#          'cracked black pepper': 1763,
#          'pinto beans': 1762,
#          'pineapple': 1760,
#          'garam masala': 1734,
#          'tomato puree': 1727,
#          'russet potatoes': 1726,
#          'sage': 1719,
#          'bell peppers': 1708,
#          'dark chocolate': 1679,
#          'yogurt': 1670,
#          'fresh garlic': 1668,
#          'unsweetened applesauce': 1664,
#          'tomato juice': 1663,
#          'boneless chicken breasts': 1655,
#          'frozen spinach': 1654,
#          'peas': 1651,
#          'mango': 1644,
#          'seasoning': 1641,
#          'dill': 1641,
#          'granny smith apples': 1634,
#          'yellow cornmeal': 1633,
#          'whole kernel corn': 1630,
#          'provolone cheese': 1628,
#          'sunflower seeds': 1625,
#          'fresh basil leaf': 1624,
#          'cornflour': 1615,
#          'artichoke hearts': 1615,
#          'cooked ham': 1614,
#          'poultry seasoning': 1610,
#          'nonstick cooking spray': 1607,
#          'parmigiano-reggiano cheese': 1605,
#          'prosciutto': 1605,
#          'cloves': 1604,
#          'chicken breast': 1603,
#          'raspberries': 1600,
#          'broccoli florets': 1599,
#          'yellow onions': 1595,
#          'corn syrup': 1595,
#          'fresh blueberries': 1589,
#          'pumpkin puree': 1580,
#          'pecan halves': 1580,
#          'golden raisin': 1571,
#          'panko breadcrumbs': 1565,
#          'celery salt': 1565,
#          'ground cardamom': 1552,
#          'fresh coarse ground black pepper': 1551,
#          'yellow bell pepper': 1547,
#          'egg noodles': 1547,
#          'cajun seasoning': 1545,
#          'chicken thighs': 1543,
#          'black peppercorns': 1540,
#          'oranges': 1539,
#          'rice wine vinegar': 1532,
#          'light soy sauce': 1521,
#          'unflavored gelatin': 1518,
#          'brown rice': 1514,
#          'celery rib': 1511,
#          'half-and-half cream': 1507,
#          'greek yogurt': 1504,
#          'splenda granular': 1486,
#          'light cream': 1485,
#          'tuna': 1482,
#          'pepperoni': 1482,
#          'fresh basil leaves': 1480,
#          'large shrimp': 1476,
#          'shredded coconut': 1474,
#          'quick-cooking oats': 1472,
#          'dill weed': 1471,
#          'soymilk': 1468,
#          'green olives': 1466,
#          'lemon rind': 1466,
#          'baking potatoes': 1465,
#          'american cheese': 1464,
#          'fresh orange juice': 1458,
#          'oyster sauce': 1453,
#          'beef': 1449,
#          'cinnamon sticks': 1446,
#          'ice cubes': 1446,
#          'spring onions': 1440,
#          'hamburger': 1433,
#          'unsweetened chocolate': 1420,
#          'liquid smoke': 1417,
#          'dark rum': 1415,
#          'ground turmeric': 1412,
#          'table salt': 1408,
#          'diced green chilies': 1400,
#          'limes': 1399,
#          'grape tomatoes': 1397,
#          'cannellini beans': 1394,
#          'vegetable shortening': 1389,
#          'egg substitute': 1388,
#          'fresh coriander': 1387,
#          'mustard seeds': 1385,
#          'linguine': 1381,
#          'pesto sauce': 1376,
#          'white chocolate chips': 1375,
#          'garbanzo beans': 1371,
#          'red kidney beans': 1370,
#          'medium shrimp': 1370,
#          'button mushrooms': 1369,
#          'bean sprouts': 1367,
#          'romano cheese': 1366,
#          'prepared horseradish': 1360,
#          'fresh mint leaves': 1359,
#          'white chocolate': 1359,
#          'catsup': 1358,
#          'lime zest': 1352,
#          'old fashioned oats': 1350,
#          'wheat germ': 1345,
#          'refried beans': 1345,
#          'cranberries': 1344,
#          'green bell peppers': 1344,
#          'white rice': 1343,
#          'italian sausage': 1338,
#          'coconut oil': 1338,
#          'whole cloves': 1338,
#          'minced garlic cloves': 1338,
#          'sauerkraut': 1334,
#          'cashews': 1331,
#          'taco seasoning mix': 1331,
#          'sweet potato': 1330,
#          'mashed potatoes': 1327,
#          'hamburger buns': 1324,
#          'bourbon': 1320,
#          'yellow squash': 1311,
#          'lasagna noodles': 1311,
#          'penne pasta': 1311,
#          'corn flakes': 1307,
#          'fennel seed': 1303,
#          'whipped topping': 1303,
#          'marshmallows': 1302,
#          'tomato soup': 1301,
#          'chocolate': 1296,
#          'caraway seed': 1295,
#          'gruyere cheese': 1295,
#          'long grain rice': 1294,
#          'smoked paprika': 1294,
#          'mint': 1290,
#          'dried apricot': 1282,
#          'chicken wings': 1282,
#          'parsley flakes': 1281,
#          'couscous': 1281,
#          'fresh parsley leaves': 1272,
#          'sweet red pepper': 1268,
#          'kalamata olive': 1265,
#          'red food coloring': 1264,
#          'fresh sage': 1254,
#          'pears': 1249,
#          'pizza sauce': 1245,
#          'low-fat milk': 1245,
#          'canned pumpkin': 1241,
#          'apple cider': 1239,
#          'eggplants': 1238,
#          'fresh gingerroot': 1236,
#          'white flour': 1234,
#          'vanilla essence': 1233,
#          'mandarin oranges': 1232,
#          '2%25 low-fat milk': 1231,
#          'hazelnuts': 1229,
#          'light sour cream': 1228,
#          'diced onion': 1226,
#          'onion soup mix': 1214,
#          'red peppers': 1210,
#          'unsweetened cocoa': 1209,
#          'mustard powder': 1207,
#          'old bay seasoning': 1201,
#          'italian dressing': 1198,
#          'orange peel': 1188,
#          'fresh cranberries': 1187,
#          'self-rising flour': 1185,
#          'salad oil': 1182,
#          'dry yeast': 1181,
#          'boneless skinless chicken thighs': 1174,
#          'yellow mustard': 1172,
#          'sun-dried tomato': 1171,
#          'green cabbage': 1171,
#          'marjoram': 1171,
#          'lemon pepper': 1170,
#          'monterey jack pepper cheese': 1169,
#          'fresh cilantro leaves': 1162,
#          'orange marmalade': 1162,
#          'fresh flat-leaf parsley': 1156,
#          'ground chuck': 1150,
#          'marinara sauce': 1147,
#          'basmati rice': 1141,
#          'milk chocolate chips': 1141,
#          'chocolate syrup': 1135,
#          'whole tomatoes': 1131,
#          'sausage': 1131,
#          'dried onion flakes': 1131,
#          'mangoes': 1129,
#          'snow peas': 1124,
#          'horseradish': 1123,
#          'lemongrass': 1122,
#          'tahini': 1121,
#          'pure maple syrup': 1117,
#          'light mayonnaise': 1112,
#          'ice water': 1109,
#          'cream of celery soup': 1096,
#          'pineapple chunks': 1092,
#          'creme fraiche': 1092,
#          'sweetened flaked coconut': 1090,
#          'quinoa': 1087,
#          'fresh tarragon': 1086,
#          'vegetables': 1083,
#          'italian seasoned breadcrumbs': 1083,
#          'red chili powder': 1080,
#          'turmeric powder': 1079,
#          'roasted red pepper': 1075,
#          'sweet paprika': 1075,
#          'rhubarb': 1072,
#          'frozen mixed vegetables': 1070,
#          'chili': 1070,
#          'ranch dressing': 1065,
#          'roasted red peppers': 1065,
#          'water chestnuts': 1064,
#          'firm tofu': 1062,
#          'chicken bouillon cubes': 1060,
#          'quick oats': 1058,
#          'macadamia nuts': 1057,
#          '1%25 low-fat milk': 1051,
#          'instant vanilla pudding': 1051,
#          'superfine sugar': 1048,
#          'baby spinach leaves': 1048,
#          'self raising flour': 1046,
#          'iceberg lettuce': 1044,
#          'pie crusts': 1041,
#          'miracle whip': 1040,
#          'macaroni': 1039,
#          'reduced-sodium chicken broth': 1035,
#          'yukon gold potatoes': 1029,
#          'fresh green beans': 1027,
#          'cooked bacon': 1021,
#          'butterscotch chips': 1020,
#          'orzo pasta': 1019,
#          'cherry pie filling': 1019,
#          'salted butter': 1018,
#          'salt %26 fresh ground pepper': 1017,
#          'sun-dried tomatoes': 1016,
#          'teriyaki sauce': 1014,
#          'tarragon': 1012,
#          'dried marjoram': 1010,
#          'lemon wedge': 1007,
#          'cilantro leaf': 1005,
#          'ice cube': 1000,
#          'pasta sauce': 996,
#          'tequila': 996,
#          'sunflower oil': 995,
#          'poppy seed': 993,
#          'salmon': 993,
#          'dried sage': 986,
#          'corn oil': 979,
#          'chorizo sausage': 977,
#          'unbleached flour': 975,
#          'miniature marshmallows': 974,
#          'chopped tomato': 972,
#          'lemon extract': 971,
#          'lentils': 969,
#          'vanilla bean': 967,
#          'noodles': 964,
#          'whole wheat bread': 960,
#          'toasted sesame oil': 956,
#          'pistachios': 952,
#          'arborio rice': 950,
#          'part-skim mozzarella cheese': 949,
#          'self-raising flour': 949,
#          'kale': 949,
#          'cooked chicken breasts': 947,
#          'toasted sesame seeds': 941,
#          'cumin powder': 938,
#          'arugula': 936,
#          'puff pastry': 932,
#          'red cabbage': 932,
#          'ghee': 926,
#          'mexican blend cheese': 925,
#          'rice flour': 922,
#          'bisquick': 916,
#          'pancetta': 912,
#          'creamed corn': 911,
#          'kahlua': 906,
#          'pork': 906,
#          'mirin': 905,
#          'frozen whipped topping': 903,
#          'ground mustard': 902,
#          'ground almonds': 898,
#          'asiago cheese': 898,
#          'fat free cream cheese': 898,
#          'vegetable oil cooking spray': 896,
#          'dried parsley flakes': 894,
#          'apricot preserves': 894,
#          'condensed cream of mushroom soup': 893,
#          'italian parsley': 892,
#          'dried tarragon': 892,
#          'saffron': 890,
#          'pizza dough': 889,
#          'maraschino cherry': 889,
#          'new potatoes': 885,
#          'lime wedge': 881,
#          'coriander leaves': 881,
#          'mascarpone cheese': 881,
#          'lettuce leaves': 879,
#          'instant coffee': 878,
#          'chicken breast halves': 876,
#          'mini marshmallows': 875,
#          'yellow pepper': 874,
#          'cooked brown rice': 874,
#          'fresh parmesan cheese': 870,
#          'tortillas': 870,
#          'smoked salmon': 869,
#          'creole seasoning': 868,
#          'light cream cheese': 864,
#          'fresh italian parsley': 863,
#          'fresh breadcrumb': 862,
#          'onion salt': 862,
#          'chicken pieces': 860,
#          'low-fat sour cream': 859,
#          'olive': 857,
#          'pie crust': 857,
#          'smoked sausage': 852,
#          'red chilies': 852,
#          'baguette': 852,
#          'maraschino cherries': 850,
#          'ground chicken': 849,
#          'dried dill': 849,
#          'currants': 847,
#          'diced tomato': 844,
#          'graham crackers': 844,
#          'bacon bits': 844,
#          'ground cayenne pepper': 843,
#          'condensed milk': 842,
#          'cardamom': 841,
#          'powdered milk': 841,
#          'angel hair pasta': 839,
#          'cooked turkey': 838,
#          'plain breadcrumbs': 832,
#          'mint leaf': 831,
#          'turkey': 830,
#          'portabella mushrooms': 827,
#          'coriander powder': 826,
#          'fresh tomatoes': 825,
#          'enchilada sauce': 825,
#          'dry onion soup mix': 822,
#          'reduced sodium soy sauce': 821,
#          'coriander seed': 820,
#          'lard': 820,
#          'italian bread': 818,
#          'double cream': 816,
#          'dark sesame oil': 814,
#          'food coloring': 814,
#          'fresh pineapple': 807,
#          'whole wheat pastry flour': 804,
#          'frozen strawberries': 804,
#          'pork sausage': 804,
#          'feta': 802,
#          'gelatin': 802,
#          'beef bouillon cubes': 798,
#          'dried thyme leaves': 797,
#          'white onions': 797,
#          'cranberry juice': 794,
#          'beets': 793,
#          'peppercorns': 790,
#          'seasoned bread crumbs': 787,
#          'granny smith apple': 787,
#          'lemons%2c juice of': 786,
#          'white cake mix': 786,
#          'nonfat sour cream': 784,
#          'rice krispies': 783,
#          'lemon%2c rind of': 782,
#          'gorgonzola': 781,
#          'parsnips': 781,
#          'pumpkin seeds': 780,
#          'prawns': 779,
#          'coffee': 778,
#          'frozen orange juice concentrate': 773,
#          'cream-style corn': 772,
#          'cherries': 769,
#          'oreo cookies': 768,
#          'tart apples': 766,
#          'ground flax seeds': 766,
#          'orange%2c zest of': 766,
#          'fresh thyme leave': 762,
#          'grand marnier': 762,
#          'spinach leaves': 762,
#          'green chili': 761,
#          'kalamata olives': 761,
#          'fresh garlic cloves': 760,
#          'sherry wine vinegar': 755,
#          'broccoli floret': 755,
#          'vanilla instant pudding mix': 755,
#          'olives': 754,
#          'great northern beans': 753,
#          'brewed coffee': 751,
#          'agave nectar': 749,
#          'white beans': 745,
#          'condensed cream of chicken soup': 745,
#          'fat free sour cream': 744,
#          'ginger ale': 744,
#          'sweet onions': 743,
#          'dried oregano leaves': 743,
#          'watercress': 739,
#          'colby-monterey jack cheese': 738,
#          'bisquick baking mix': 737,
#          'vidalia onion': 737,
#          'chipotle chiles in adobo': 736,
#          'golden syrup': 736,
#          'poppy seeds': 734,
#          'low-fat cheddar cheese': 729,
#          'wild rice': 729,
#          'sugar substitute': 727,
#          'chipotle chile in adobo': 724,
#          'baking cocoa': 724,
#          'brie cheese': 723,
#          'extra lean ground beef': 723,
#          'tomatoes and green chilies': 723,
#          'limes%2c juice of': 722,
#          'dried cherries': 721,
#          'tofu': 718,
#          'instant yeast': 718,
#          'pearl barley': 713,
#          'refrigerated crescent dinner rolls': 713,
#          'cooked white rice': 711,
#          'berries': 711,
#          'chili flakes': 710,
#          'black-eyed peas': 709,
#          'alfredo sauce': 708,
#          'english cucumber': 706,
#          'oregano leaves': 703,
#          'wide egg noodles': 703,
#          'flank steaks': 701,
#          'lettuce leaf': 699,
#          'nonfat dry milk powder': 698,
#          'soft breadcrumbs': 698,
#          'sourdough bread': 697,
#          'crystallized ginger': 696,
#          'fettuccine': 696,
#          'kielbasa': 694,
#          'dried apricots': 692,
#          'rice wine': 690,
#          'marinated artichoke hearts': 690,
#          'instant coffee granules': 689,
#          'asparagus spears': 687,
#          'boneless pork chops': 687,
#          'sake': 686,
#          'fresh asparagus': 685,
#          'whole chickens': 685,
#          'italian salad dressing': 684,
#          'wonton wrappers': 683,
#          'low fat cottage cheese': 681,
#          'green food coloring': 680,
#          'low-fat mayonnaise': 680,
#          'minced garlic clove': 680,
#          'apricot jam': 680,
#          'radishes': 679,
#          'artificial sweetener': 675,
#          'reduced-fat cream cheese': 675,
#          'cognac': 674,
#          'crisco': 672,
#          'anchovy fillets': 672,
#          'long-grain rice': 666,
#          'fresh lemon rind': 666,
#          'plain low-fat yogurt': 665,
#          'mixed vegetables': 665,
#          'fresh raspberry': 664,
#          'smooth peanut butter': 664,
#          'dried italian seasoning': 663,
#          'beef stew meat': 662,
#          'green peas': 662,
#          'fresh raspberries': 662,
#          'ranch dressing mix': 661,
#          'bicarbonate of soda': 660,
#          'guacamole': 660,
#          'chilies': 659,
#          'lump crabmeat': 658,
#          'desiccated coconut': 657,
#          'red chili pepper': 656,
#          'dark soy sauce': 655,
#          'oat bran': 654,
#          'chili beans': 654,
#          'saltine crackers': 654,
#          'fennel bulb': 653,
#          'chicken bouillon cube': 652,
#          'flax seed': 652,
#          'sliced water chestnuts': 651,
#          'peppermint extract': 650,
#          'stock': 649,
#          'ground lamb': 648,
#          'canned tomatoes': 647,
#          'cumin seeds': 647,
#          'vanilla yogurt': 646,
#          'shiitake mushrooms': 644,
#          'pita bread': 643,
#          'frozen raspberries': 641,
#          'spring onion': 640,
#          'cremini mushrooms': 640,
#          'dried dill weed': 639,
#          'rotini pasta': 638,
#          'instant chocolate pudding mix': 638,
#          'xanthan gum': 636,
#          'red capsicum': 635,
#          'chicken bouillon': 634,
#          'low-fat buttermilk': 633,
#          'tamari': 631,
#          'beans': 629,
#          'bow tie pasta': 629,
#          'barley': 627,
#          'whole berry cranberry sauce': 626,
#          'wine vinegar': 626,
#          'fruit': 625,
#          'soya sauce': 622,
#          'penne': 621,
#          'part-skim ricotta cheese': 620,
#          'mixed salad greens': 619,
#          'frozen puff pastry': 619,
#          'pear': 618,
#          'cantaloupe': 617,
#          'tilapia fillets': 617,
#          'whole chicken': 616,
#          'frozen chopped broccoli': 614,
#          'chunky salsa': 614,
#          'condensed tomato soup': 614,
#          'plain fat-free yogurt': 614,
#          'deli ham': 613,
#          'saffron thread': 612,
#          'fresh mozzarella cheese': 612,
#          'picante sauce': 611,
#          'thyme leaves': 610,
#          'instant rice': 610,
#          'wheat flour': 610,
#          'pimientos': 610,
#          'red chile': 608,
#          'lean ground turkey': 608,
#          'milk chocolate': 608,
#          'amaretto': 607,
#          'extra-sharp cheddar cheese': 607,
#          'mussels': 607,
#          'sweet chili sauce': 606,
#          'raw sugar': 606,
#          'salted peanuts': 606,
#          'chuck roast': 604,
#          'phyllo dough': 603,
#          'pineapple tidbits': 603,
#          'club soda': 603,
#          'fine sea salt': 603,
#          'corn kernels': 602,
#          'frozen corn kernels': 601,
#          'caramels': 600,
#          'sweet pickle relish': 599,
#          'philadelphia cream cheese': 599,
#          'reduced-fat sour cream': 599,
#          'tuna in water': 598,
#          'olive oil flavored cooking spray': 597,
#          'green chili peppers': 597,
#          'star anise': 597,
#          'stewing beef': 597,
#          'roma tomato': 596,
#          'pitted dates': 592,
#          'mini chocolate chip': 592,
#          'sea scallops': 591,
#          'sliced ripe olives': 591,
#          'vanilla wafers': 591,
#          'frozen broccoli': 589,
#          'watermelon': 589,
#          'crunchy peanut butter': 588,
#          'ritz crackers': 587,
#          'flax seed meal': 586,
#          'diced tomatoes with juice': 584,
#          'lemon%2c juice and zest of': 584,
#          'raspberry jam': 583,
#          'beef brisket': 583,
#          'fontina cheese': 581,
#          'marshmallow creme': 577,
#          'napa cabbage': 574,
#          'fresh tomato': 573,
#          'plum tomato': 573,
#          'chili paste': 571,
#          'nutritional yeast': 568,
#          'pecorino romano cheese': 568,
#          'mint leaves': 567,
#          'dried breadcrumbs': 567,
#          'rotel tomatoes': 564,
#          'fresh coriander leaves': 564,
#          'white mushrooms': 563,
#          'minced ginger': 562,
#          'fresh breadcrumbs': 561,
#          'cooked shrimp': 560,
#          'roasting chickens': 560,
#          'mild cheddar cheese': 560,
#          'frozen blueberries': 560,
#          'pork and beans': 559,
#          'granulated garlic': 559,
#          'graham cracker pie crust': 556,
#          'fresh thyme leaves': 556,
#          'unsweetened chocolate squares': 556,
#          'summer squash': 556,
#          'pitted black olives': 556,
#          'skinless chicken breasts': 554,
#          'french-fried onions': 553,
#          'light olive oil': 553,
#          'low-fat cream cheese': 553,
#          'crouton': 552,
#          'chili pepper': 552,
#          'mixed spice': 552,
#          'hot dogs': 552,
#          'salad dressing': 552,
#          'peppercorn': 550,
#          'raw shrimp': 548,
#          'corned beef': 547,
#          'dark corn syrup': 547,
#          'dried chipotle powder': 546,
#          'scallops': 546,
#          'peach': 546,
#          'coconut extract': 545,
#          'radish': 543,
#          'almond milk': 543,
#          'miniature marshmallow': 543,
#          'fat-free mayonnaise': 543,
#          'herbes de provence': 542,
#          'whiskey': 541,
#          'plain nonfat yogurt': 541,
#          'smoked ham': 540,
#          'baked beans': 539,
#          ...})

# %%
ingredients, counts = zip(*ingredient_counter.most_common(10))

plt.bar(ingredients, counts)
plt.xticks(rotation=30)
plt.xlabel("Ingredients")
plt.ylabel("Occurences In Recipes")
plt.title("Top 10 Most Common Ingredients In Recipes")
plt.show()
